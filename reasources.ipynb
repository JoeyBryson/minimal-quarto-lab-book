# %% [markdown]
# analytical proof there is a phase transition:
# https://renormalwords.wordpress.com/2017/04/20/the-peierls-argument/
#
# Contains an argument for SW satisfying DB
# https://arxiv.org/pdf/2205.07226
#
#
# http://www.stat.phys.kyushu-u.ac.jp/B4/Papers/Feynman-StatMech-Chap-1-3-Org.pdf
#
# Swendsen-Wang Algorythm explanation
# https://www.inference.org.uk/itila/swendsen.pdf
#
# Mean Field theory derivations
# https://cpb-us-w2.wpmucdn.com/u.osu.edu/dist/3/67057/files/2018/09/Ising_model_MFT-25b1klj.pdf
#
# assymetric critical exponents
# https://arxiv.org/pdf/1508.07852
#
# introductiuon to renormalization groups
# http://www.scholarpedia.org/article/Critical_Phenomena:_field_theoretical_approach
#
# Onsager's solutions
# https://journals.aps.org/pr/pdf/10.1103/PhysRev.65.117
#
# phase transitions in the context of biological systems
# file:///home/joey/Downloads/SSRN-id1397677.pdf
#
# discussion of psudocritical temperature
# https://watermark.silverchair.com/95-4-733.pdf?token=AQECAHi208BE49Ooan9kkhW_Ercy7Dm3ZL_9Cf3qfKAc485ysgAAA0owggNGBgkqhkiG9w0BBwagggM3MIIDMwIBADCCAywGCSqGSIb3DQEHATAeBglghkgBZQMEAS4wEQQM346nv6ylEVaY_wwJAgEQgIIC_dKsXeCqJae7scxKbmP6I8sjR0FrfK8Cyvz34mmN6Cz3H7yrmh_EejCipf258vmG6hRwLuIsNjkQrU_1zzl06lIO7h6Igq2gpp9APf7RqnwMtAoibl1his86QZZRaskdMBFsvbJJVzI9dHQ8UWPobeE0BWqxBIFNyfM17cKQaAgQAxK3fNgj6x1sBFZTmFrTQQMR_WC5TdGPYi6_I2WKWZken87gTT-2emCfFrpur6gw1a0b9WZbCuyEmAOkpay6NqfP7yAIup547LNu-TC868OVAmpl3tTQOiMROws_aNkHcmTTCs7JTRr28wM5DfkX8o_EOAlp9rU22Aqh8jKDFnJQAzubx7t2L2kcdUoySee discussions, stats, and author profiles for this publication at: https://www.researchgate.net/publication/222687003
# Correlations, Risk NY8EpJ0cRS2edDvy4NPobe_J3Xdslk0p8Ujd0OV1mhkXUskay2vv0GuOqzxJOAa0EIynKF0cjnubyKw45rcxRz1H2qhIhpcn9TEQTGfaC7Ekr8DfLNCLcSJcxwoNxhagmfJgCCajUe6h49FhQmmghOy6tPrRat8UM2mQ_Ixd9OIcBlg2xVrgp8rb4pJ3slfZmX9_I33b6C2iUjjqLi48DkB2_DR16h4zP0JcWqb5ax-hqDnfTNtdF7A1Eqkbh1qmCTB_0i-eVn-WZbN0zctZvKdpyDxks-6BICYIl9a9wZs6TSWYfFJZD0v9fm6tIpv9RJ3Ge7j6ED2xwVixdVxsU-Xzf-K8OLAktux7lqvUVNnhVWWY2vUy-joMBOJT7YWCjY45hrzPqWKGnhORrLrkCzKb0bfCHgaSthqgdSYDaBWp01WmI906vXLORQamSaS2GRa6zMbsoyaCfm6CDgSP6XquZKcYOZNSQ7_pwpAo6svCFfdngeohXWyIXNkAiJWjZ8yWYeV2iV7PleCVCHd77KHLtkCwnD56TkitKm74x891iVZ-RSVDKE9PuM8DlphqoPCzIFvF5CM-8QNkZkxKB8P-tjkJ5rOz3j0Ce3KeqsfgJ2zwzWHyDSF2qM1JNL5QZ_ef11M35s7BmEyF3rVFpw
#
# Binder discussion
# http://www.lptms.ger distinguishes the sign of the magne-
# tization. The reason for this choice is that it can be
# meaningfully compared to the distributions of finite
# systems {P~I)(s) and P~P)(s), as introduced above}, for
# which there is no spontaneous magnetization. Thus
# also for arbitu-psud.fr/membres/trizac/Ens/PCS/TD1_Binder.pdf
#
# phd theses on Ising
# https://www.bristol.ac.uk/physics/media/theory-theses/smith-t-thesis.pdf
#
# The binder cumulant's sensitivity to boundrary conditions
# file:///home/joey/Downloads/e2006-00209-7.pdf
#
# Binder's seminal paper introducing $U_L$
# file:///home/joey/Downloads/BF01293604.pdf
# https://link.springer.com/article/10.1007/bf01293604?utm_source=chatgpt.com
#
# Critical Dynamical exponent z = z=2.1665
# https://journals.aps.org/pre/pdf/10.1103/PhysRevE.108.034118
